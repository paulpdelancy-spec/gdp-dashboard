# %% [markdown]
# <a href="https://colab.research.google.com/github/paulpdelancy-spec/gdp-dashboard/blob/main/Master_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =================================================================
# 🛡️ SOVEREIGN ENGINE v45.1: THE RAW TRUTH UNIFIED CORE
# =================================================================
# UPGRADES: Raw Text Fallback | Invisible Data Insurance | Heartbeat
# =================================================================

# !pip install -q -U google-genai==1.64.0 newspaper3k lxml_html_clean edge-tts fpdf2 mutagen pytz

import os, datetime, time, pytz, smtplib, asyncio, random, re
import edge_tts
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
from google.genai import Client
from newspaper import Article, Config
from fpdf import FPDF

# ⚠️ PASTE YOUR KEYS HERE
GEMINI_API_KEY = "AIzaSyDuqasPNoAm9hI2JFoGLf1a1i3C9qq9ubo"
GMAIL_APP_PASSWORD = "ppfh hzqp qlbf ijti"

FINANCIAL_NODES = ["www.cmegroup.com", "www.nyse.com", "www.nasdaq.com", "www.cboe.com", "www.bloomberg.com", "www.reuters.com/finance", "www.lseg.com/en", "www.hkex.com.hk", "www.jpx.co.jp/english", "www.sse.com.cn", "www.nseindia.com", "www.tmx.com", "www.euronext.com/en", "www.deutsche-boerse.com", "www.six-group.com/en", "www.sgx.com", "www.asx.com.au", "www.bseindia.com", "www.jse.co.za/trade", "www.idx.co.id/en-us", "www.set.or.th/en/home", "www.bursamalaysia.com", "www.twse.com.tw/en", "www.nadex.com"]
SPORTS_NODES = ["www.espn.com", "www.nfl.com", "www.nba.com", "www.premierleague.com", "www.skysports.com", "www.cbssports.com", "www.mlb.com", "www.nhl.com", "www.bundesliga.com", "www.laliga.com/en-GB", "www.legaseriea.it/it", "ligue1.com", "www.mlssoccer.com", "www.iplt20.com", "www.afl.com.au", "www.nrl.com", "www.ligaportugal.pt", "eredivisie.nl", "www.cfl.ca", "www.ligamx.net", "www.cbf.com.br", "www.jleague.jp/en", "sports.sina.com.cn/csl", "www.afa.com.ar"]

CLIENT_LEDGER = {"paul.pdelancy@gmail.com": [2, 6, 10, 14, 18, 22], "paulacumberbatch@yahoo.com": [2, 6, 10, 14, 18, 22]}

STRIPE_LINKS = """
--- STEWARDSHIP UPGRADE OPTIONS ---
1 Report/Day: $10/mo (https://buy.stripe.com/9B66oIcTW85N16o4xe8g00a) | $120/yr (https://buy.stripe.com/7sY5kE5rufyf9CUe7O8g00b)
2 Reports/Day: $19/mo (https://buy.stripe.com/fZu7sMcTW5XF9CUgfW8g00c) | $228/yr (https://buy.stripe.com/4gM8wQ5rubhZ4iAd3K8g00d)
3 Reports/Day: $28/mo (https://buy.stripe.com/aFabJ25rubhZ16obZG8g00e) | $336/yr (https://buy.stripe.com/8x25kE3jmcm3dTa4xe8g00f)
4 Reports/Day: $36/mo (https://buy.stripe.com/5kQ8wQ2fi0DleXe0gY8g00g) | $432/yr (https://buy.stripe.com/aFa4gA8DGadV8yQfbS8g00h)
5 Reports/Day: $45/mo (https://buy.stripe.com/4gM6oIdY04TB16o1l28g00i) | $540/yr (https://buy.stripe.com/6oUbJ2aLOcm37uM3ta8g00j)
6 Reports/Day: $54/mo (https://buy.stripe.com/6oU8wQ4nqfyfaGYe7O8g00k) | $648/yr (https://buy.stripe.com/3cIdRa8DG4TBeXe3ta8g00l)
"""

class BrandedFPDF(FPDF):
    def add_watermark(self, img_path):
        if os.path.exists(img_path):
            with self.local_context(fill_opacity=0.15):
                self.image(img_path, x=40, y=80, w=130)

class StewardshipAgent:
    def __init__(self):
        self.client = Client(api_key=GEMINI_API_KEY)
        self.model_id = "gemini-2.0-flash"
        self.agent_image = "image_0.png.jfif"

    def clean_for_pdf(self, text):
        return text.encode('ascii', 'ignore').decode('ascii')

    def deep_scrape(self, url):
        config = Config()
        config.browser_user_agent = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'
        config.request_timeout = 10
        try:
            article = Article(f"https://{url}", config=config)
            article.download(); article.parse()
            return article.text[:500] if len(article.text) > 50 else article.meta_description[:500]
        except: return "Node Offline."

    def process_nodes(self, nodes, sector_name):
        full_analysis = f"\n--- {sector_name} ANALYSIS ---\n"
        chunks = [nodes[i:i + 4] for i in range(0, len(nodes), 4)]
        for idx, chunk in enumerate(chunks):
            print(f"🚜 Harvesting {sector_name} (Batch {idx+1}/{len(chunks)})...")
            batch_data = ""
            for url in chunk:
                scrape_res = self.deep_scrape(url)
                batch_data += f"\n[{url}]: {scrape_res}"

            prompt = f"As Ezra and Jessa, provide 2 high-value stewardship insights from this data: {batch_data}. Focus on productivity and resource recovery."
            try:
                response = self.client.models.generate_content(model=self.model_id, contents=prompt)
                ai_text = response.text.strip()
                # 🛡️ THE RAW TRUTH FALLBACK
                if not ai_text or len(ai_text) < 10:
                    ai_text = f"[RAW DATA FALLBACK]: {batch_data[:300]}..."
                full_analysis += ai_text + "\n"
            except:
                full_analysis += f"[SYSTEM OVERRIDE]: Data retrieved from {len(chunk)} nodes but AI summary bypassed.\n"
        return full_analysis

    async def generate_assets(self, report_text):
        a_file, p_file = "briefing.mp3", "report.pdf"
        await edge_tts.Communicate(report_text[:6000], "en-US-AndrewNeural").save(a_file)
        pdf = BrandedFPDF(); pdf.set_author("Paul C. II")
        pdf.add_page(); pdf.add_watermark(self.agent_image)
        if os.path.exists(self.agent_image):
            pdf.image(self.agent_image, x=10, y=10, w=40); pdf.ln(35)
        pdf.set_font("helvetica", "B", 16)
        pdf.cell(0, 10, "Sovereign Stewardship Pulse Audit", new_x="LMARGIN", new_y="NEXT", align='C')
        pdf.set_font("helvetica", size=10); pdf.ln(5)
        pdf.multi_cell(0, 7, self.clean_for_pdf(report_text))
        pdf.add_page(); pdf.add_watermark(self.agent_image)
        pdf.set_font("helvetica", "B", 14); pdf.cell(0, 10, "Subscription Management", new_x="LMARGIN", new_y="NEXT")
        pdf.set_font("helvetica", size=9); pdf.multi_cell(0, 6, self.clean_for_pdf(STRIPE_LINKS))
        pdf.output(p_file)
        return a_file, p_file

    def send_tiered_email(self, a_file, p_file, current_hour):
        active = [email for email, hrs in CLIENT_LEDGER.items() if current_hour in hrs]
        if not active: return
        msg = MIMEMultipart()
        msg['Subject'] = f"🛡️ Sovereign Pulse: {datetime.datetime.now().strftime('%m/%d %I:%M %p')}"
        msg['From'] = f"Ezra & Jessa <paul.pdelancy@gmail.com>"; msg['To'] = ", ".join(active)
        msg.attach(MIMEText("Your authorized stewardship audit is attached.\n\nSigned Management.\nGod Bless.", 'plain'))
        for f in [a_file, p_file]:
            with open(f, "rb") as file_data:
                part = MIMEApplication(file_data.read(), Name=os.path.basename(f))
                part['Content-Disposition'] = f'attachment; filename="{os.path.basename(f)}"'
                msg.attach(part)
        with smtplib.SMTP_SSL("smtp.gmail.com", 465) as s:
            s.login("paul.pdelancy@gmail.com", GMAIL_APP_PASSWORD)
            s.sendmail("paul.pdelancy@gmail.com", active, msg.as_string())
        print(f"📧 Dispatch complete to {len(active)} stewards.")

async def run_master_engine():
    agent = StewardshipAgent(); est = pytz.timezone('US/Eastern')
    print("🚀 Sovereign Engine v45.1 Ignited. Raw Truth Protocol Active.")
    while True:
        now = datetime.datetime.now(est)
        sched = [2, 6, 10, 14, 18, 22]
        if now.hour in sched and now.minute < 5:
            f_rep = agent.process_nodes(FINANCIAL_NODES, "FINANCE")
            s_rep = agent.process_nodes(SPORTS_NODES, "SPORTS")
            audio, pdf = await agent.generate_assets(f"GLOBAL STEWARDSHIP REPORT\n{f_rep}\n{s_rep}")
            agent.send_tiered_email(audio, pdf, now.hour)
            await asyncio.sleep(300)
        print(f"💓 Heartbeat: {now.strftime('%I:%M %p')} EST | System Stable | Monitoring 48 Nodes")
        await asyncio.sleep(300)

await run_master_engine()
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 2.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.0/81.0 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 42.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.8/728.8 kB 37.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.1/211.1 kB 16.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.1/327.1 kB 23.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 13.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 29.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.9/105.9 kB 8.7 MB/s eta 0:00:00
#   Building wheel for tinysegmenter (setup.py) ... done
#   Building wheel for feedfinder2 (setup.py) ... done
#   Building wheel for jieba3k (setup.py) ... done
#   Building wheel for sgmllib3k (setup.py) ... done
# 🚀 Sovereign Engine v45.0 Ignited. Full Disclosure Protocol Active.
# 💓 Heartbeat: 05:13 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:18 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:23 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:28 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:33 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:38 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:43 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:48 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:53 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 05:58 AM EST | System Stable | Monitoring 48 Nodes
# 📡 Pulse Detected at 6:00. Harvesting...
# 🚜 Harvesting FINANCE (Batch 1/6)...
# 🚜 Harvesting FINANCE (Batch 2/6)...
# 🚜 Harvesting FINANCE (Batch 3/6)...
# 🚜 Harvesting FINANCE (Batch 4/6)...
# 🚜 Harvesting FINANCE (Batch 5/6)...
# 🚜 Harvesting FINANCE (Batch 6/6)...
# 🚜 Harvesting SPORTS (Batch 1/6)...
# 🚜 Harvesting SPORTS (Batch 2/6)...
# 🚜 Harvesting SPORTS (Batch 3/6)...
# 🚜 Harvesting SPORTS (Batch 4/6)...
# 🚜 Harvesting SPORTS (Batch 5/6)...
# 🚜 Harvesting SPORTS (Batch 6/6)...
# /tmp/ipykernel_3991/3695437938.py:95: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, "Sovereign Stewardship Pulse Audit", ln=True, align='C')
# /tmp/ipykernel_3991/3695437938.py:105: DeprecationWarning: The parameter "ln" is deprecated since v2.5.2. Instead of ln=True use new_x=XPos.LMARGIN, new_y=YPos.NEXT.
#   pdf.cell(0, 10, "Subscription Management", ln=True)
# 📧 Dispatch complete to 2 stewards.
# 💓 Heartbeat: 06:03 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:16 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:21 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:26 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:31 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:36 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:41 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:46 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:51 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 06:56 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 07:01 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 07:06 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 07:11 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 07:16 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 07:21 AM EST | System Stable | Monitoring 48 Nodes
# 💓 Heartbeat: 07:26 AM EST | System Stable | Monitoring 48 Nodes
