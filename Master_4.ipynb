# %% [markdown]
# <a href="https://colab.research.google.com/github/paulpdelancy-spec/gdp-dashboard/blob/main/Master_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- STEP 1: INSTALLATION & IMPORTS ---
# !pip install -q -U pymupdf requests pandas google-genai newspaper3k lxml_html_clean edge-tts fpdf2 mutagen pytz

import os, datetime, time, pytz, smtplib, asyncio, random, re, fitz, requests
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.application import MIMEApplication
from google.genai import Client
from newspaper import Article, Config
from fpdf import FPDF

# --- CONFIGURATION (THE KEYS) ---
GEMINI_API_KEY = "AIzaSyDuqasPNoAm9hI2JFoGLf1a1i3C9qq9ubo"
GMAIL_APP_PASSWORD = "ppfh hzqp qlbf ijti"
RECIPIENT_EMAIL = "paul.pdelancy@gmail.com" # Change to "paulacumberbatch@yahoo.com" for second run
EXPIRY_WINDOW_HOURS = 4

# --- THE GROUND-TRUTH NODES ---
URL_TARGETS = [
    "www.cmegroup.com/markets/metals/precious/gold.html",
    "www.cmegroup.com/markets/metals/precious/silver.html",
    "www.tmx.com/en/mining/", "www.nseindia.com", "www.bseindia.com",
    "www.lseg.com", "www.hkex.com.hk", "www.fifa.com",
    "www.premierleague.com", "www.nba.com", "www.espn.com/soccer/"
]

# --- PART A: THE SENTINEL SEALER (MATRIX FIX) ---
def apply_sentinel_seal(input_pdf, recipient):
    print(f"Applying Sentinel Seal for: {recipient}...")
    doc = fitz.open(input_pdf)
    expiry_time = (datetime.datetime.now() + datetime.timedelta(hours=EXPIRY_WINDOW_HOURS)).strftime("%I:%M %p EST")

    # Correct Matrix for 45-degree rotation (Fixes ValueError)
    m = fitz.Matrix(45)

    for page in doc:
        # Red Expiry Header
        page.insert_text((400, 30), f"EXPIRES: {expiry_time}", fontsize=11, color=(1, 0, 0))

        # Tiled Watermark Logic
        for x in range(-100, 700, 250):
            for y in range(0, 900, 200):
                page.insert_text((x, y), recipient,
                                 fontsize=35,
                                 morph=(fitz.Point(x, y), m),
                                 color=(0.8, 0.8, 0.8), fill_opacity=0.15)

    output_path = f"FINAL_STOCKED_{recipient.replace('@', '_')}.pdf"
    doc.save(output_path)
    return output_path

# --- PART B: THE VAULT & DISPATCH ---
def get_ephemeral_link(file_path):
    print("Re-Arming Secure Bridge via Alternative Vault...")
    url = "https://file.io"
    # Adding a 'User-Agent' makes the script look like a real browser
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
    }
    try:
        with open(file_path, "rb") as f:
            # We add a 20-second timeout to handle node latency
            r = requests.post(url, files={"file": f}, params={"expires": "4h"}, headers=headers, timeout=20)

        if r.status_code == 200:
            return r.json().get("link")
        else:
            print(f"Server Response Code: {r.status_code}")
            return None
    except Exception as e:
        print(f"Connection Error: {e}")
        return None






def send_secure_link(email, vault_url):
    msg = MIMEMultipart()
    msg['Subject'] = f"🛡️ SECURE ASSET: Pulse {datetime.datetime.now().strftime('%I:%M %p')}"
    msg['From'] = "Stewardship Office <paul.pdelancy@gmail.com>"; msg['To'] = email
    body = f"This intelligence is ephemeral.\n\nONE-TIME ACCESS LINK: {vault_url}\n\nExpires in 4 hours."
    msg.attach(MIMEText(body, 'plain'))
    with smtplib.SMTP_SSL("smtp.gmail.com", 465) as s:
        s.login("paul.pdelancy@gmail.com", GMAIL_APP_PASSWORD)
        s.sendmail("paul.pdelancy@gmail.com", email, msg.as_string())
    print(f"✅ Secure Link Dispatched to {email}")

# --- PART C: THE HARVEST ENGINE ---
async def execute_pulse_run(recipient):
    print(f"🚀 Sovereign Engine v45.7: Initiating Pulse for {recipient}")

    # 1. Generate Base Report (Simplified for Manual Test)
    doc = fitz.open()
    page = doc.new_page()
    page.insert_text((72, 72), "Sovereign Engine v45.7 - Manual Verification", fontsize=18)
    page.insert_text((72, 110), f"Timestamp: {datetime.datetime.now().strftime('%I:%M %p')} | 48-Node Analysis Active", fontsize=11)
    page.insert_text((72, 130), "Market Status: Above-Ground Observation Mode - Ceasefire Watch.", fontsize=11)
    base_file = "raw_harvest.pdf"
    doc.save(base_file)

    # 2. Seal and Arm
    sealed_file = apply_sentinel_seal(base_file, recipient)
    vault_url = get_ephemeral_link(sealed_file)

    # 3. Dispatch
    if vault_url:
        send_secure_link(recipient, vault_url)
        print("\n" + "█"*50)
        print(f"SUCCESS: SENTINEL LINK ARMED")
        print(f"URL: {vault_url}")
        print("█"*50)
    else:
        print("CRITICAL ERROR: Vault Connection Failed.")

# --- TRIGGER ---
await execute_pulse_run(RECIPIENT_EMAIL)
# Out:
# 🚀 Sovereign Engine v45.7: Initiating Pulse for paul.pdelancy@gmail.com
# Applying Sentinel Seal for: paul.pdelancy@gmail.com...
# Re-Arming Secure Bridge via Alternative Vault...
# Connection Error: Expecting value: line 1 column 1 (char 0)
# CRITICAL ERROR: Vault Connection Failed.
